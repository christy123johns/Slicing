# %%
import pandas as pd
data=pd.read_excel('/content/TopSellingAlbums.xlsx')
data
# Out:
#             Artist                            Album  ...  Soundtrack Rating
# 0  Michael Jackson                         Thriller  ...         NaN   10.0
# 1            AC/DC                    Back in Black  ...         NaN    9.5
# 2       Pink Floyd        The Dark Side of the Moon  ...         NaN    9.0
# 3  Whitney Houston                    The Bodyguard  ...           Y    8.5
# 4        Meat Loaf                  Bat Out of Hell  ...         NaN    8.0
# 5           Eagles  Their Greatest Hits (1971-1975)  ...         NaN    7.5
# 6         Bee Gees             Saturday Night Fever  ...           Y    7.0
# 7    Fleetwood Mac                          Rumours  ...         NaN    6.5
#
# [8 rows x 10 columns]

# %%
# Access to the column Length
x=data[['Length']]
x
# Out:
#      Length
# 0  00:42:19
# 1  00:42:11
# 2  00:42:49
# 3  00:57:44
# 4  00:46:33
# 5  00:43:08
# 6  01:15:54
# 7  00:40:01

# %%
#To access column length in a series format
y=data['Length'] 
y
# Out:
# 0    00:42:19
# 1    00:42:11
# 2    00:42:49
# 3    00:57:44
# 4    00:46:33
# 5    00:43:08
# 6    01:15:54
# 7    00:40:01
# Name: Length, dtype: object

# %%
# Access to multiple columns
y=data[['Artist','Length','Genre']]
y
# Out:
#             Artist    Length                        Genre
# 0  Michael Jackson  00:42:19               pop, rock, R&B
# 1            AC/DC  00:42:11                    hard rock
# 2       Pink Floyd  00:42:49             progressive rock
# 3  Whitney Houston  00:57:44               R&B, soul, pop
# 4        Meat Loaf  00:46:33  hard rock, progressive rock
# 5           Eagles  00:43:08   rock, soft rock, folk rock
# 6         Bee Gees  01:15:54                        disco
# 7    Fleetwood Mac  00:40:01                    soft rock

# %%
# Access the value on the first row and the first column
data.iloc[0,0]
# Out:
# 'Michael Jackson'

# %%
data.iloc[1,0]
# Out:
# 'AC/DC'

# %%
data.iloc[4,2]
# Out:
# 1977

# %%
# Access the column using the variable name
data.loc[5,'Artist']
# Out:
# 'Eagles'

# %%
data.loc[7,'Genre']
# Out:
# 'soft rock'

# %%
data.loc[1:7,'Genre']
# Out:
# 1                      hard rock
# 2               progressive rock
# 3                 R&B, soul, pop
# 4    hard rock, progressive rock
# 5     rock, soft rock, folk rock
# 6                          disco
# 7                      soft rock
# Name: Genre, dtype: object

# %%
# slicing the dataframe
data.iloc[0:6,2:4]
# Out:
#    Released    Length
# 0      1982  00:42:19
# 1      1980  00:42:11
# 2      1973  00:42:49
# 3      1992  00:57:44
# 4      1977  00:46:33
# 5      1976  00:43:08

# %%
data.iloc[1:4,0:4]
# Out:
#             Artist                      Album  Released    Length
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44

# %% [markdown]
# Another data Data of football

# %%
data1=pd.read_excel('/content/Football.xlsx')
data1
# Out:
#         Team  Score     Opposition  ...           Player Height  Weight
# 0   Adelaide     71         Sydney  ...     Atkins, Rory    186      85
# 1   Adelaide     71         Sydney  ...      Brown, Luke    181      81
# 2   Adelaide     71         Sydney  ...     Crouch, Brad    186      85
# 3   Adelaide     71         Sydney  ...     Crouch, Matt    182      80
# 4   Adelaide     71         Sydney  ...       Davis, Ben    187      85
# 5   Adelaide     71         Sydney  ...   Fogarty, Darcy    193      94
# 6   Adelaide     71         Sydney  ...  Frampton, Billy    200      96
# 7   Adelaide     71         Sydney  ...     Gibbs, Bryce    188      84
# 8   Adelaide     71         Sydney  ...    Jones, Chayce    180      77
# 9   Adelaide     71         Sydney  ...      Kelly, Jake    190      89
# 10  Adelaide     71         Sydney  ...      Laird, Rory    177      81
# 11  Adelaide     71         Sydney  ...     Lynch, Tom T    193      88
